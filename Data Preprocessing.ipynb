# %%
import pandas as pd

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-ac541150-bf5a-4d8b-a3a6-31e4ff765ae8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac541150-bf5a-4d8b-a3a6-31e4ff765ae8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('data cleaning.zip')

# %%
df
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                        NaN    Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL      NaN   SUMA N GHOSHAL
# 2124                     NaN    Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address  AgeStart  AgeEnd  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...        16      17
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...        19      20
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...        19      20
# ...

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# {'data cleaning.zip': b'PK\x03\x04-\x00\x00\x00\x08\x00\x04R5O}\x8d\x19\x02\xff\xff\xff\xff\xff\xff\xff\xff\r\x00\x14\x00cleandata.csv\x01\x00\x10\x00\xe42\x05\x00\x00\x00\x00\x00\x0cX\x01\x00\x00\x00\x00\x00\xcc\xbdY\x8f\xebX\x92&\xf8\x1e\xbf\xe2 \x9ef\x00\xc9%R;\xe6\xe9H\xa2\x8b\x94DRI\x8a\xee\xe9\xf7\xa9\x13\x93\xd1U\x85\xa9\xca\x062\xa3\x1a\xe8\xf9\xf5c\xcbY\xecp\x95\xdf\xc8j\x0c\x12\xc8p\x97_Q\xa6\xb3\xd8\xfa\xd9g\xc5_\xfe\xe3\xb7\xd9\xe5\xb7\xbf\xfd\xf5\xb7\xbf\xcf\xaa\xdf\xfe\xfd/\xbf\xff\xdb\xff\xfcm\xa6\xff\xfa\xd7\xbf\xff\xf6\x8f\x7f\xcc\xf4\xbf\xfcV\xff\xfe\x97\xbf\xff\x8e?$\x7f\xfb\xeb,\xfd\xed\xdf\xfe\xe5_\x7f\xe7\x97\xf8g|\xf5\xf8\x9f\xff\xf6\xef\xbf\xcf\xce\x7f\xf9\xfd\xb7\xd9\xf9\xdf\xfe\xf1\xfb\x0c\xfe\xfe\xfbo\xbf\\\xbf\xcag6{\xff\xed?\xfe\xf2\xef\xbf\xcd\xd4%I\x9ez\xf6\xebL\xa9\x99JT\x14\x1f\x94VuZ\xdeT\xa1/\xbaR\x8f*;\xeb/\x95\xeb\xea\x96<\xd5)-?o\xea\x9c\xdc\xd3L\x15\t\xfc\xf9\x99\x14OU\xc3\xcb\xe5]]\xde\x9eo\xc77\x95\x14\'u\xd7\x1f\x89*\xca\xea\x99\xaaD\xd7O\xf3
# ...

# %% [markdown]
# # **EDA**[Exploratory Data Analysis]

# %%
df.shape
# Out:
# (2127, 12)

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Relative', 'Address', 'AgeStart', 'AgeEnd',
#        'HeightStart', 'HeightEnd', 'Built', 'Date', 'Dist', 'State'],
#       dtype='object')

# %%
df.head()
# Out:
#          Name  Gender        Relative  \
# 0       JYOTI  Female           GEETA
# 1    ABHISHEK    Male    MUKE SHKUMAR
# 2         NaN    Male    RAJE SHKUMAR
# 3  JAIPRAKASH    Male   KAMA LKISHORE
# 4      SADDAM    Male          MUNN A
#
#                                              Address  AgeStart  AgeEnd  \
# 0  ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...        16      17
# 1  , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...        19      20
# 2  , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...        19      20
# 3  , , 15/286, KALYANPURI DELHI KALYA NPURI EAST ...        24      25
# 4  , , 19-20, KABOOTAR MARKET WELCOM DELHI WELCO ...        21      22
#
#    HeightStart  HeightEnd         Built  Date                       Dist  \
# 0        122.0      183.0  normalmedium   NaN  G.T.B. ENCLAVE/NORTH EAST
# 1        153.0      183.0          thin   NaN          PUNJABI BAGH/WEST
# 2        153.0      183.0          thin   NaN       NEW ASHOK NAGAR/EAST
# ...

# %%
df.tail()
# Out:
#                         Name Gender          Relative  \
# 2122                  MANOJ    Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL     NaN   SUMA N GHOSHAL
# 2124                     NaN   Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY    Male         KULD EEP
# 2126                  DEPTY    Male        RAM AVTAR
#
#                                                 Address  AgeStart  AgeEnd  \
# 2122  , , T 35 RAM A ROAD MOOLCHAND COLONY DELHI ADA...        24      25
# 2123  , M ale, I 158 SUND ER NAGARI DELHI NORTH EAST...        15      16
# 2124  , HOUSE N O 446 NAUGHRA MOHALLAH TUGLAKABAD VI...        15      16
# 2125  , , H NO 771 S EC 6 R K PURAM NEW DELHI R. K. ...        58      59
# 2126  , , HOUSE NO 81/13 CHURRIYA MOHALLAH N DELHI T...         5       7
#
#       HeightStart  HeightEnd         Built  Date                     Dist  \
# 2122        153.0      275.0          thin   NaN  ADARSH NAGAR/NORTH WEST
# ...

# %%
df.describe()
# Out:
#           AgeStart       AgeEnd  HeightStart    HeightEnd  Date
# count  2127.000000  2127.000000  2094.000000  2094.000000   0.0
# mean     25.962388    26.952515   168.523400   176.548233   NaN
# std      14.698394    14.721309   314.559716   385.352640   NaN
# min       1.000000     1.000000     3.000000     0.000000   NaN
# 25%      17.000000    18.000000   153.000000    92.000000   NaN
# 50%      22.000000    23.000000   153.000000   183.000000   NaN
# 75%      30.000000    31.000000   153.000000   183.000000   NaN
# max      96.000000    97.000000  4664.000000  5578.000000   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1560 non-null   object
#  1   Gender       2010 non-null   object
#  2   Relative     2125 non-null   object
#  3   Address      2127 non-null   object
#  4   AgeStart     2127 non-null   int64
#  5   AgeEnd       2127 non-null   int64
#  6   HeightStart  2094 non-null   float64
#  7   HeightEnd    2094 non-null   float64
#  8   Built        2115 non-null   object
#  9   Date         0 non-null      float64
#  10  Dist         2127 non-null   object
#  11  State        1996 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 199.5+ KB

# %% [markdown]
# # **DATA CLEANING**

# %%
df.isnull()
# Out:
#        Name  Gender  Relative  Address  AgeStart  AgeEnd  HeightStart  \
# 0     False   False     False    False     False   False        False
# 1     False   False     False    False     False   False        False
# 2      True   False     False    False     False   False        False
# 3     False   False     False    False     False   False        False
# 4     False   False     False    False     False   False        False
# ...     ...     ...       ...      ...       ...     ...          ...
# 2122  False   False     False    False     False   False        False
# 2123  False    True     False    False     False   False        False
# 2124   True   False     False    False     False   False        False
# 2125  False   False     False    False     False   False        False
# 2126  False   False     False    False     False   False         True
#
#       HeightEnd  Built  Date   Dist  State
# 0         False  False  True  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Name            567
# Gender          117
# Relative          2
# Address           0
# AgeStart          0
# AgeEnd            0
# HeightStart      33
# HeightEnd        33
# Built            12
# Date           2127
# Dist              0
# State           131
# dtype: int64

# %%
df.new = df.iloc[:,0:10]

# %%
df.new
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                        NaN    Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL      NaN   SUMA N GHOSHAL
# 2124                     NaN    Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address  AgeStart  AgeEnd  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...        16      17
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...        19      20
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...        19      20
# ...

# %%
df.new.isnull().sum()
# Out:
# Name            567
# Gender          117
# Relative          2
# Address           0
# AgeStart          0
# AgeEnd            0
# HeightStart      33
# HeightEnd        33
# Built            12
# Date           2127
# dtype: int64

# %%
df.new.dropna()
# Out:
# Empty DataFrame
# Columns: [Name, Gender, Relative, Address, AgeStart, AgeEnd, HeightStart, HeightEnd, Built, Date]
# Index: []

# %%
df.new.isnull().mean()
# Out:
# Name           0.266573
# Gender         0.055007
# Relative       0.000940
# Address        0.000000
# AgeStart       0.000000
# AgeEnd         0.000000
# HeightStart    0.015515
# HeightEnd      0.015515
# Built          0.005642
# Date           1.000000
# dtype: float64

# %% [markdown]
# NOTE : As the above example, here in all columns and rows there is a NAN value..
